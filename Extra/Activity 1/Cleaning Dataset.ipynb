# %%
import modin.pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("archive/200k_news_category.csv")

# %%
cleaned_df = df[["title", "content", "category"]]

# %%
cleaned_df
# Out:
#                                                     title  \
# 0       Zareen Khan's lawyer issues statement on arres...
# 1       What is Women's Reservation Bill, demanded by ...
# 2       IIT Kanpur Director Abhay Karandikar appointed...
# 3       Time stops for you: Mahindra as he praises PM ...
# 4       BJP MP Satish Dubey injured after car rams int...
# ...                                                   ...
# 210795  Ambulance service started in Telangana under S...
# 210796  Cheating case against Telugu actor Viswant Dud...
# 210797  SC grants bail to Kannada actress Ragini Dwive...
# 210798  Katrina's sister Isabelle to star in 'Suswagat...
# 210799  Thank you for choosing me: Ayushmann on wife T...
#
#                                                   content    category
# 0       After a Kolkata court issued an arrest warrant...  Technology
# 1       At an all-party meeting convened by the govern...    Politics
# ...
