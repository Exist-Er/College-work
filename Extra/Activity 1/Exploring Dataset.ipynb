# %%
import modin.pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("archive/200k_news_category.csv")[["title", "content", "category"]]

# %%
df.info()
print("\nShape : ", df.shape)

print("\nColumn featuers:")
df.describe()
# Out:
# <class 'modin.pandas.dataframe.DataFrame'>
# RangeIndex: 210800 entries, 0 to 210799
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   title     210799 non-null  object
#  1   content   210800 non-null  object
#  2   category  210800 non-null  object
# dtypes: object(3)
# memory usage: 4.8+ MB
#
# Shape :  (210800, 3)
#
# Column featuers:
#                  title                                            content  \
# count           210799                                             210800
# unique          209664                                             210800
# top     Sunday Roundup  After a Kolkata court issued an arrest warrant...
# freq                90                                                  1
#
#          category
# count      210800
# unique         10
# top     Lifestyle
# freq        64130

# %% [raw]
# Here we see that:
#     we are working with 3 columns [title, conntent, category]
#     there are ~201k training examples.
#     none of the content is duplicated
#     there are 10 unique categories for the training examples

# %%
print("Checking for null values:")
print(df.isnull().sum())

print("\nChecking duplicate rows:")
print(df[df.duplicated()])

print("\nChecking the number of records per categor:")
print(df.groupby("category").count())
# Out:
# Checking for null values:
# title       1
# content     0
# category    0
# dtype: int64
#
# Checking duplicate rows:
# Empty DataFrame
# Columns: [title, content, category]
# Index: []
#
# Checking the number of records per categor:
#                title  content
# category
# Business       14195    14195
# Education      14733    14733
# Entertainment  10237    10237
# Health         23938    23938
# Lifestyle      64129    64130
# Politics       36603    36603
# Science         6647     6647
# Sports         13447    13447
# Technology     25943    25943
# War              927      927

# %% [raw]
# Here we see that:
#     the title column has one missing value
#     theere are no duplicate rows in the data
